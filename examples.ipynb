# %% [markdown]
# # Decision tree visualization

# %%
import IPython, graphviz, re
from io import StringIO
from IPython.display import Image
import numpy as np
import pandas as pd
import math
from sklearn import tree
from sklearn.datasets import load_boston, load_iris
from collections import defaultdict

# %%
from animl.trees import *
from animl.viz.trees import *

regr = tree.DecisionTreeRegressor(max_depth=5, random_state=666)
boston = load_boston()

X_train = pd.DataFrame(boston.data, columns=boston.feature_names)
y_train = boston.target

regr = regr.fit(X_train, y_train)

dtreeviz(regr, boston.data, boston.target, target_name="price", feature_names=boston.feature_names, orientation="TD")

#dtreeviz(clf, data, iris.target, orientation="TD", class_names=["setosa", "versicolor", "virginica"])

# %%
clf = tree.DecisionTreeClassifier(max_depth=2, random_state=666)
iris = load_iris()

data = pd.DataFrame(iris.data)
data.columns = iris.feature_names
iris.target_names

clf = clf.fit(data, iris.target)

dtreeviz(clf, data, iris.target, orientation="TD", feature_names=data.columns, target_name="type", class_names=iris.target_names)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-3151b83b0771> in <module>()
#       8 clf = clf.fit(data, iris.target)
#       9
# ---> 10 dtreeviz(clf, data, iris.target, orientation="TD", feature_names=data.columns, target_name="type", class_names=iris.target_names)
#
# ~/github/animl/animl/viz/trees.py in dtreeviz(tree_model, X_train, y_train, feature_names, target_name, class_names, precision, orientation)
#      76
#      77     node_split_viz(shadow_tree.root, X_train, y_train, filename=None, target_name=target_name,
# ---> 78                    figsize=(15, 4))
#      79
#      80     n_classes = shadow_tree.nclasses()
#
# ~/github/animl/animl/viz/trees.py in node_split_viz(node, X, y, target_name, filename, showx, showy, figsize, label_fontsize)
#     160         ax.axis('off')
#     161
# --> 162     if isinstance(X,pd.DataFrame):
#     163         X = X.values
#     164     X = X[:,node.feature()]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2482         """Return the cached item, item represents a label indexer."""
#    2483         cache = self._item_cache
# -> 2484         res = cache.get(item)
#    2485         if res is None:
#    2486             values = self._data.get(item)
#
# TypeError: unhashable type: 'slice'
